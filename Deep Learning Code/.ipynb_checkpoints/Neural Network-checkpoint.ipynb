# %%
#IMPORTS
import os
import cv2
import tqdm
import pickle
import random
import numpy as np
import mediapipe as mp
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.python.util.deprecation as deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False

# %%
#PATH
dataset_path = "Clean_dataset"

# %%
#MEDIAPOSE
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True,
    model_complexity=2,
    enable_segmentation=True,
    min_detection_confidence=0.5)

# %%
#CLASS LABELS
class_labels = {
    "downdog": 0,
    "goddess": 1,
    "plank": 2, 
    "tree": 3,
    "warrior2": 4
}
pose_label = ["Downdog","Goddess","Plank","Tree","Warrior II"]

# %%
#MODEL
def create_model():
    model = keras.Sequential()
    model.add(
        layers.Conv1D(
            filters=16,
            kernel_size=3,
            activation=keras.activations.relu,
            padding="same",
            input_shape=(33, 2)
        )
    )
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.2))
    model.add(layers.MaxPooling1D())
    model.add(
        layers.Conv1D(
            filters=16,
            kernel_size=3,
            activation=keras.activations.relu,
            padding="same",
        )
    )
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.2))
    model.add(layers.Flatten())
    model.add(layers.Dense(5, activation=keras.activations.softmax))
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.0001),
        loss='categorical_crossentropy',
        metrics=[tf.keras.metrics.CategoricalAccuracy(name="accuracy")]
    )
    return model

# %%
#TRAIN MODEL
def train_model(model, train_dataset, val_dataset):
    history = model.fit(train_dataset, epochs=100, validation_data=val_dataset)
    model.save("save/predict.model")
    return history

# %%
#PLOTTING ACCURACY
def plot_accgraph(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

# %%
#LOAD DATASET
def load_dataset(
        dataset_label,
        data_path,
        class_labels,
    ):
    data = []
    labels = []
    for class_name in class_labels.keys():
        path = f"{data_path}/{dataset_label}/{class_name}"
        print(f"Loading {dataset_label} Data for Class Name: {class_name}")
        for filename in tqdm.tqdm(os.listdir(path), position=0):
            image = cv2.imread(f"{path}/{filename}")
            results = pose.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
            if not results.pose_landmarks:
                continue
            sample = []
            for lm in results.pose_landmarks.landmark:
                sample.append((lm.x, lm.y))
            data.append(sample)
            label_sample = np.zeros(5)
            label_sample[class_labels[class_name]] = 1
            labels.append(label_sample)
    return np.array(data), np.array(labels)

# %%
#LOAD DATA
def load_data(data_path, class_labels):
    train_data, train_labels = load_dataset(
        "TRAIN",
        data_path,
        class_labels,
    )
    test_data, test_labels = load_dataset(
        "TEST",
        data_path,
        class_labels,
    )
    train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels)).batch(32)
    test_dataset = tf.data.Dataset.from_tensor_slices((test_data, test_labels)).batch(32)
    return train_dataset, test_dataset

# %%
#LOADING DATASET
train_dataset, test_dataset = load_data(dataset_path, class_labels)
# Out:
# Loading TRAIN Data for Class Name: downdog
# 100%|████████████████████████████████████████████████████████████████████████████████| 247/247 [00:29<00:00,  8.24it/s]
# Loading TRAIN Data for Class Name: goddess
# 100%|████████████████████████████████████████████████████████████████████████████████| 125/125 [00:16<00:00,  7.71it/s]
# Loading TRAIN Data for Class Name: plank
# 100%|████████████████████████████████████████████████████████████████████████████████| 135/135 [00:17<00:00,  7.73it/s]
# Loading TRAIN Data for Class Name: tree
# 100%|████████████████████████████████████████████████████████████████████████████████| 151/151 [00:21<00:00,  7.11it/s]
# Loading TRAIN Data for Class Name: warrior2
# 100%|████████████████████████████████████████████████████████████████████████████████| 269/269 [00:35<00:00,  7.62it/s]
# Loading TEST Data for Class Name: downdog
# 100%|██████████████████████████████████████████████████████████████████████████████████| 90/90 [00:12<00:00,  7.43it/s]
# Loading TEST Data for Class Name: goddess
# 100%|██████████████████████████████████████████████████████████████████████████████████| 90/90 [00:11<00:00,  7.69it/s]
# Loading TEST Data for Class Name: plank
# 100%|██████████████████████████████████████████████████████████████████████████████████| 90/90 [00:13<00:00,  6.67it/s]
# Loading TEST Data for Class Name: tree
# 100%|██████████████████████████████████████████████████████████████████████████████████| 90/90 [00:14<00:00,  6.29it/s]
# Loading TEST Data for Class Name: warrior2
# 100%|██████████████████████████████████████████████████████████████████████████████████| 90/90 [00:12<00:00,  7.30it/s]

# %%
#LOADING MODEL
model = create_model()

# %%
#TRAINING MODEL
history=train_model(model, train_dataset, test_dataset)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 0s 14ms/step - loss: 2.2502 - accuracy: 0.1995 - val_loss: 1.6151 - val_accuracy: 0.2036
# Epoch 2/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.9758 - accuracy: 0.2807 - val_loss: 1.6088 - val_accuracy: 0.2036
# Epoch 3/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.7853 - accuracy: 0.3371 - val_loss: 1.6042 - val_accuracy: 0.2036
# Epoch 4/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.7203 - accuracy: 0.3709 - val_loss: 1.5987 - val_accuracy: 0.2036
# Epoch 5/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.5978 - accuracy: 0.4205 - val_loss: 1.5911 - val_accuracy: 0.2036
# Epoch 6/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.5276 - accuracy: 0.4453 - val_loss: 1.5799 - val_accuracy: 0.2036
# Epoch 7/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.4071 - accuracy: 0.4837 - val_loss: 1.5628 - val_accuracy: 0.2036
# Epoch 8/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.2879 - accuracy: 0.5062 - val_loss: 1.5369 - val_accuracy: 0.2036
# Epoch 9/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.2608 - accuracy: 0.5186 - val_loss: 1.4982 - val_accuracy: 0.2036
# Epoch 10/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.2414 - accuracy: 0.5175 - val_loss: 1.4511 - val_accuracy: 0.2353
# Epoch 11/100
# 28/28 [==============================] - 0s 3ms/step - loss: 1.1611 - accuracy: 0.5468 - val_loss: 1.3928 - val_accuracy: 0.3100
# Epoch 12/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.0880 - accuracy: 0.5829 - val_loss: 1.3260 - val_accuracy: 0.3869
# Epoch 13/100
# 28/28 [==============================] - 0s 2ms/step - loss: 1.0543 - accuracy: 0.6020 - val_loss: 1.2526 - val_accuracy: 0.4661
# Epoch 14/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.9724 - accuracy: 0.6291 - val_loss: 1.1753 - val_accuracy: 0.5158
# Epoch 15/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.9310 - accuracy: 0.6437 - val_loss: 1.1017 - val_accuracy: 0.6244
# Epoch 16/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.9266 - accuracy: 0.6561 - val_loss: 1.0346 - val_accuracy: 0.7127
# Epoch 17/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.8476 - accuracy: 0.6742 - val_loss: 0.9738 - val_accuracy: 0.7308
# Epoch 18/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.8669 - accuracy: 0.6742 - val_loss: 0.9192 - val_accuracy: 0.7217
# Epoch 19/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.8217 - accuracy: 0.7046 - val_loss: 0.8730 - val_accuracy: 0.7149
# Epoch 20/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.7792 - accuracy: 0.7317 - val_loss: 0.8364 - val_accuracy: 0.7421
# Epoch 21/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7647 - accuracy: 0.7260 - val_loss: 0.8058 - val_accuracy: 0.7353
# Epoch 22/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7496 - accuracy: 0.7272 - val_loss: 0.7837 - val_accuracy: 0.7285
# Epoch 23/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6918 - accuracy: 0.7565 - val_loss: 0.7687 - val_accuracy: 0.7308
# Epoch 24/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7004 - accuracy: 0.7565 - val_loss: 0.7560 - val_accuracy: 0.7262
# Epoch 25/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6672 - accuracy: 0.7644 - val_loss: 0.7445 - val_accuracy: 0.7240
# Epoch 26/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6913 - accuracy: 0.7565 - val_loss: 0.7365 - val_accuracy: 0.7104
# Epoch 27/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6581 - accuracy: 0.7734 - val_loss: 0.7274 - val_accuracy: 0.7036
# Epoch 28/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6313 - accuracy: 0.7869 - val_loss: 0.7207 - val_accuracy: 0.7014
# Epoch 29/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5950 - accuracy: 0.8106 - val_loss: 0.7110 - val_accuracy: 0.7014
# Epoch 30/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5930 - accuracy: 0.7948 - val_loss: 0.6998 - val_accuracy: 0.7104
# Epoch 31/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5889 - accuracy: 0.8083 - val_loss: 0.6973 - val_accuracy: 0.7104
# Epoch 32/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5500 - accuracy: 0.8016 - val_loss: 0.6919 - val_accuracy: 0.7104
# Epoch 33/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5614 - accuracy: 0.8117 - val_loss: 0.6875 - val_accuracy: 0.7149
# Epoch 34/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5153 - accuracy: 0.8365 - val_loss: 0.6824 - val_accuracy: 0.7149
# Epoch 35/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4817 - accuracy: 0.8444 - val_loss: 0.6752 - val_accuracy: 0.7172
# Epoch 36/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4853 - accuracy: 0.8422 - val_loss: 0.6674 - val_accuracy: 0.7217
# Epoch 37/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5115 - accuracy: 0.8219 - val_loss: 0.6559 - val_accuracy: 0.7353
# Epoch 38/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5075 - accuracy: 0.8275 - val_loss: 0.6490 - val_accuracy: 0.7443
# Epoch 39/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5046 - accuracy: 0.8365 - val_loss: 0.6500 - val_accuracy: 0.7398
# Epoch 40/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4699 - accuracy: 0.8455 - val_loss: 0.6493 - val_accuracy: 0.7421
# Epoch 41/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4658 - accuracy: 0.8523 - val_loss: 0.6419 - val_accuracy: 0.7466
# Epoch 42/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4665 - accuracy: 0.8501 - val_loss: 0.6327 - val_accuracy: 0.7534
# Epoch 43/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4578 - accuracy: 0.8512 - val_loss: 0.6249 - val_accuracy: 0.7534
# Epoch 44/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4279 - accuracy: 0.8670 - val_loss: 0.6191 - val_accuracy: 0.7579
# Epoch 45/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4108 - accuracy: 0.8625 - val_loss: 0.6154 - val_accuracy: 0.7579
# Epoch 46/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4046 - accuracy: 0.8681 - val_loss: 0.6114 - val_accuracy: 0.7647
# Epoch 47/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4153 - accuracy: 0.8579 - val_loss: 0.6076 - val_accuracy: 0.7602
# Epoch 48/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3916 - accuracy: 0.8681 - val_loss: 0.6028 - val_accuracy: 0.7624
# Epoch 49/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3893 - accuracy: 0.8760 - val_loss: 0.5955 - val_accuracy: 0.7715
# Epoch 50/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3736 - accuracy: 0.8726 - val_loss: 0.5899 - val_accuracy: 0.7715
# Epoch 51/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3964 - accuracy: 0.8782 - val_loss: 0.5883 - val_accuracy: 0.7670
# Epoch 52/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8861 - val_loss: 0.5871 - val_accuracy: 0.7715
# Epoch 53/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3557 - accuracy: 0.8839 - val_loss: 0.5835 - val_accuracy: 0.7805
# Epoch 54/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3635 - accuracy: 0.8805 - val_loss: 0.5788 - val_accuracy: 0.7828
# Epoch 55/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8929 - val_loss: 0.5801 - val_accuracy: 0.7828
# Epoch 56/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3394 - accuracy: 0.9064 - val_loss: 0.5733 - val_accuracy: 0.7851
# Epoch 57/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3294 - accuracy: 0.8929 - val_loss: 0.5691 - val_accuracy: 0.7851
# Epoch 58/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3188 - accuracy: 0.8952 - val_loss: 0.5678 - val_accuracy: 0.7851
# Epoch 59/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3514 - accuracy: 0.8828 - val_loss: 0.5659 - val_accuracy: 0.7851
# Epoch 60/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3190 - accuracy: 0.9076 - val_loss: 0.5610 - val_accuracy: 0.7873
# Epoch 61/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3117 - accuracy: 0.9030 - val_loss: 0.5555 - val_accuracy: 0.7896
# Epoch 62/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3173 - accuracy: 0.8997 - val_loss: 0.5565 - val_accuracy: 0.7873
# Epoch 63/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3233 - accuracy: 0.8974 - val_loss: 0.5548 - val_accuracy: 0.7896
# Epoch 64/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2949 - accuracy: 0.9019 - val_loss: 0.5546 - val_accuracy: 0.7873
# Epoch 65/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2793 - accuracy: 0.9121 - val_loss: 0.5521 - val_accuracy: 0.7873
# Epoch 66/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2921 - accuracy: 0.9154 - val_loss: 0.5505 - val_accuracy: 0.7873
# Epoch 67/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2857 - accuracy: 0.9132 - val_loss: 0.5505 - val_accuracy: 0.7873
# Epoch 68/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2887 - accuracy: 0.9188 - val_loss: 0.5499 - val_accuracy: 0.7873
# Epoch 69/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2746 - accuracy: 0.9222 - val_loss: 0.5488 - val_accuracy: 0.7873
# Epoch 70/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2863 - accuracy: 0.9132 - val_loss: 0.5443 - val_accuracy: 0.7851
# Epoch 71/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2682 - accuracy: 0.9233 - val_loss: 0.5418 - val_accuracy: 0.7851
# Epoch 72/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2577 - accuracy: 0.9188 - val_loss: 0.5364 - val_accuracy: 0.7851
# Epoch 73/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2663 - accuracy: 0.9267 - val_loss: 0.5336 - val_accuracy: 0.7851
# Epoch 74/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2639 - accuracy: 0.9154 - val_loss: 0.5263 - val_accuracy: 0.7896
# Epoch 75/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2600 - accuracy: 0.9278 - val_loss: 0.5267 - val_accuracy: 0.7851
# Epoch 76/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2437 - accuracy: 0.9335 - val_loss: 0.5256 - val_accuracy: 0.7873
# Epoch 77/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2570 - accuracy: 0.9245 - val_loss: 0.5263 - val_accuracy: 0.7896
# Epoch 78/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2625 - accuracy: 0.9256 - val_loss: 0.5224 - val_accuracy: 0.7986
# Epoch 79/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2293 - accuracy: 0.9414 - val_loss: 0.5297 - val_accuracy: 0.7896
# Epoch 80/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2250 - accuracy: 0.9380 - val_loss: 0.5308 - val_accuracy: 0.7919
# Epoch 81/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2181 - accuracy: 0.9369 - val_loss: 0.5261 - val_accuracy: 0.7941
# Epoch 82/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2457 - accuracy: 0.9267 - val_loss: 0.5207 - val_accuracy: 0.7986
# Epoch 83/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2260 - accuracy: 0.9301 - val_loss: 0.5216 - val_accuracy: 0.7986
# Epoch 84/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2196 - accuracy: 0.9402 - val_loss: 0.5205 - val_accuracy: 0.7986
# Epoch 85/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2150 - accuracy: 0.9391 - val_loss: 0.5216 - val_accuracy: 0.7986
# Epoch 86/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 0.9335 - val_loss: 0.5182 - val_accuracy: 0.8032
# Epoch 87/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.2290 - accuracy: 0.9222 - val_loss: 0.5091 - val_accuracy: 0.8032
# Epoch 88/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 1.00 - 0s 2ms/step - loss: 0.2171 - accuracy: 0.9312 - val_loss: 0.5099 - val_accuracy: 0.8077
# Epoch 89/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2118 - accuracy: 0.9391 - val_loss: 0.5113 - val_accuracy: 0.8054
# Epoch 90/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2002 - accuracy: 0.9459 - val_loss: 0.5121 - val_accuracy: 0.8054
# Epoch 91/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2156 - accuracy: 0.9324 - val_loss: 0.5114 - val_accuracy: 0.8077
# Epoch 92/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1998 - accuracy: 0.9459 - val_loss: 0.5104 - val_accuracy: 0.8077
# Epoch 93/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2039 - accuracy: 0.9425 - val_loss: 0.5100 - val_accuracy: 0.8077
# Epoch 94/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1896 - accuracy: 0.9515 - val_loss: 0.5137 - val_accuracy: 0.8100
# Epoch 95/100
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2058 - accuracy: 0.9380 - val_loss: 0.5087 - val_accuracy: 0.8100
# Epoch 96/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.2024 - accuracy: 0.9425 - val_loss: 0.5086 - val_accuracy: 0.8100
# Epoch 97/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1844 - accuracy: 0.9493 - val_loss: 0.5118 - val_accuracy: 0.8100
# Epoch 98/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1841 - accuracy: 0.9504 - val_loss: 0.5105 - val_accuracy: 0.8100
# Epoch 99/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1933 - accuracy: 0.9459 - val_loss: 0.5118 - val_accuracy: 0.8100
# Epoch 100/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1755 - accuracy: 0.9560 - val_loss: 0.5068 - val_accuracy: 0.8100
# Assets written to: save/predict.model\assets

# %%
#ACCURACY
plot_accgraph(history)

# %%
#TRAINED MODEL
model = keras.models.load_model("save/predict.model")

# %%
#MAKE PREDICTIONS
def predict_with_static_image(model,filepath):
    input_frame = cv2.imread(filepath)
    input_frame = cv2.cvtColor(input_frame, cv2.COLOR_BGR2RGB)
    results = pose.process(image=input_frame)
    output_image = input_frame.copy()
    label = "Unknown Pose"
    accuracy = 0
    mp_drawing.draw_landmarks(output_image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
    sample = []
    for lm in results.pose_landmarks.landmark:
        sample.append((lm.x, lm.y))
    prediction = model(np.array(sample)[np.newaxis, :, :])
    p=np.array(prediction)
    label=pose_label[np.argmax(p)]
    accuracy = str(round(p[0][np.argmax(p)]*100,3)) 
    if(float(accuracy)<50):
        label = "Unknown Pose"
    return label,accuracy,output_image

# %%
#OUTPUT
def output(lab,acc,out):
    plt.figure(figsize = [10, 10])
    if(lab=="Unknown Pose"):
        plt.title(lab)
    else:
        plt.title(f"Pose: {lab} | Accuracy: {acc}%")
    plt.axis('off')
    plt.imshow(out)
    plt.show()

# %%
#PATH
path="Testing_Images/sample5.jpg"

# %%
#MAKING PREDICTIONS
lab,acc,out=predict_with_static_image(model,path)
output(lab,acc,out)
